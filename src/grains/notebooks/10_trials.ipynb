# %%
import numpy as np

# %%
n_configurations = 3
k_repetitions = 2

master_rng = np.random.default_rng(42)

trials = []
state_sampling_seeds = []
cluster_sampling_seeds = []
grain_position_sampling_seeds = []

for i in range(k_repetitions):
    state_sampling_seeds.append(int(master_rng.integers(0, 99999)))
    cluster_sampling_seeds.append(int(master_rng.integers(0, 99999)))
    grain_position_sampling_seeds.append(int(master_rng.integers(0, 99999)))

for i in range(n_configurations):
    config_seed = int(master_rng.integers(0, 99999))
    for j in range(k_repetitions):
        trials.append({
            'config_id':             i,
            'rep_id':                j,
            'config_seed':           config_seed,  # fixed per config
            'state_sampling_seed':   state_sampling_seeds[j],
            'cluster_sampling_seed': cluster_sampling_seeds[j]
        })

# %%
s = None

# s = [1,2]
if not s is None:
    print('p')

# %%
x = np.random.choice(["a",np.hanning])
x
# Out:
# <function numpy.hanning(M)>

# %%
x(100)
# Out:
# array([0.        , 0.00100666, 0.00402259, 0.00903565, 0.01602565,
#        0.02496444, 0.03581603, 0.04853673, 0.06307531, 0.07937323,
#        0.09736487, 0.11697778, 0.13813298, 0.16074529, 0.18472367,
#        0.20997155, 0.23638727, 0.26386446, 0.29229249, 0.32155689,
#        0.35153981, 0.38212053, 0.41317591, 0.4445809 , 0.47620904,
#        0.50793298, 0.53962498, 0.57115742, 0.60240333, 0.63323691,
#        0.66353398, 0.69317256, 0.72203331, 0.75      , 0.77696003,
#        0.80280484, 0.82743037, 0.85073744, 0.87263222, 0.89302655,
#        0.91183829, 0.92899171, 0.94441772, 0.95805423, 0.96984631,
#        0.97974649, 0.98771489, 0.99371944, 0.99773596, 0.99974827,
#        0.99974827, 0.99773596, 0.99371944, 0.98771489, 0.97974649,
#        0.96984631, 0.95805423, 0.94441772, 0.92899171, 0.91183829,
#        0.89302655, 0.87263222, 0.85073744, 0.82743037, 0.80280484,
#        0.77696003, 0.75      , 0.72203331, 0.69317256, 0.66353398,
#        0.63323691, 0.60240333, 0.57115742, 0.53962498, 0.50793298,
#        0.47620904, 0.4445809 , 0.41317591, 0.38212053, 0.35153981,
#        0.32155689, 0.29229249, 0.26386446, 0.23638727, 0.20997155,
#        0.18472367, 0.16074529, 0.13813298, 0.11697778, 0.09736487,
#        0.07937323, 0.06307531, 0.04853673, 0.03581603, 0.02496444,
#        0.01602565, 0.00903565, 0.00402259, 0.00100666, 0.        ])

# %%
state_sampling_seeds, cluster_sampling_seeds
# Out:
# ([8925, 65456], [77394, 43887])

# %%
trials
# Out:
# [{'config_id': 0,
#   'rep_id': 0,
#   'config_seed': 43301,
#   'state_sampling_seed': 8925,
#   'cluster_sampling_seed': 77394},
#  {'config_id': 0,
#   'rep_id': 1,
#   'config_seed': 43301,
#   'state_sampling_seed': 65456,
#   'cluster_sampling_seed': 43887},
#  {'config_id': 1,
#   'rep_id': 0,
#   'config_seed': 85858,
#   'state_sampling_seed': 8925,
#   'cluster_sampling_seed': 77394},
#  {'config_id': 1,
#   'rep_id': 1,
#   'config_seed': 85858,
#   'state_sampling_seed': 65456,
#   'cluster_sampling_seed': 43887},
#  {'config_id': 2,
#   'rep_id': 0,
#   'config_seed': 8594,
#   'state_sampling_seed': 8925,
#   'cluster_sampling_seed': 77394},
#  {'config_id': 2,
#   'rep_id': 1,
#   'config_seed': 8594,
#   'state_sampling_seed': 65456,
#   'cluster_sampling_seed': 43887}]
